# %% [markdown]
# # Application pour récupérer les lampadaires à partir d'un tronçon de route depuis Mapillary:
# ## Sources :
# https://www.mapillary.com/developer/api-documentation/points?locale=fr_FR
#
# https://geoffboeing.com/2016/11/osmnx-python-street-networks/
#
# https://stackoverflow.com/questions/50045662/gdfs-to-graph-and-vise-versa
#
# https://wiki.openstreetmap.org/wiki/Key:place
#
# https://github.com/gboeing/osmnx-examples/blob/main/notebooks/03-graph-place-queries.ipynb
#
# https://stackoverflow.com/questions/74436361/how-to-get-all-the-substates-from-a-country-in-osmnx
#
# https://wiki.openstreetmap.org/wiki/FR:Key:admin_level
#
# https://wiki.openstreetmap.org/wiki/Tag%3Aplace%3Dcity

# %% [markdown]
# Use Kernel > CIM
#
# Voir https://www.geeksforgeeks.org/using-jupyter-notebook-in-virtual-environment/

# %%
import osmnx as ox
import geopandas as gpd
import matplotlib

# %%
ox.settings.log_console = True
ox.settings.max_query_area_size = 25e12

# %% [markdown]
# ## Contours communaux pour plusieurs régions

# %%
places =["Provence-Alpes-Côte d'Azur", "Corse", "Occitanie", "Mayotte", "la Réunion", "la Nouvelle-Calédonie", "la Polynésie Française", "Wallis&Futuna"]
place = places[0] #on choisit par exemple la région PACA
tags = {'admin_level': '8'} #le niveau 8 correspond au Communes
gdf = ox.features.features_from_place(place, tags)
print(len(gdf))
# Out:
# 4035

# %% [markdown]
# ## Sélection de Lorgues

# %%
Communes=list(gdf["name"]) # On obtient la liste de toutes les Communes dans la région PACA
i=0
while i < len(Communes):
    if (type(Communes[i]) != str):
        Communes.pop(i)
    else:
        i += 1
len(Communes) # On retient que les Communes ayant un nom valable
if ("Lorgues" in Communes):
    print(True)

Commune = "Lorgues" # On choisit comme exmple la Commune de Lorgues
Communes.index(Commune) #L'indice de la Commune de Lorgue dans la liste
# Out:
# True
# 400

# %%
gdf_lorgues = gdf.loc[gdf['name'] == Commune] #le geodataframe de la Commune de Lorgues
gdf_lorgues.plot()
gdf_lorgues
# Out:
#                     addr:postcode     name  name:oc place ref:FR:SIREN  \
# element_type osmid
# relation     125337           NaN  Lorgues  Lòrgues   NaN    218300721
#
#                     source:name:oc  \
# element_type osmid
# relation     125337    ieo-bdtopoc
#
#                                                               geometry  ele  \
# element_type osmid
# relation     125337  POLYGON ((6.29093 43.48101, 6.29079 43.48119, ...  NaN
#
#                     natural note  ... name:ja-Hira  dog name:Nissart  \
# element_type osmid                ...
# relation     125337     NaN  NaN  ...          NaN  NaN          NaN
#
#                     start_date devotion pilgrimage pilgrimage:type saint_name  \
# element_type osmid
# relation     125337        NaN      NaN        NaN             NaN        NaN
#
#                     sanctuary admin_type:FR
# element_type osmid
# relation     125337       NaN           NaN
#
# [1 rows x 261 columns]

# %% [markdown]
# ## Voies sur la commune de Lorgues

# %%
import networkx as nx

graph = ox.graph_from_place(Commune, network_type='drive')
gdf_nodes, gdf_edges = ox.graph_to_gdfs(
        graph,
        nodes=True, edges=True,
        node_geometry=True,
        fill_edge_geometry=True)

routes_gdf = gdf_edges
routes_gdf.plot() #Les routes situant dans la Commune de Lorgues
# Out:
# C:\Git-Repos\cim\venv\Lib\site-packages\osmnx\graph.py:392: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   polygon = gdf_place["geometry"].unary_union
# <Axes: >

# %% [markdown]
# ## Boulevard de la République
# Route à piétoniser

# %%
routes_names=list(routes_gdf["name"]) #On obtient la liste de toutes les routes dans la commune de Lorgues
j=0
while j < len(routes_names):
    if (type(routes_names[j]) != str):
        routes_names.pop(j)
    else:
        j += 1
len(routes_names) #On retient que les routes ayant un nom valable
routes_names.sort()
if ('Boulevard de la République' in routes_names):
    print(True)
routes_pietonisation = 'Boulevard de la République' #on choisit comme exmple le Boulevard de la République
routes_names.index(routes_pietonisation) #L'indice du Boulevard de la République dans la liste
# Out:
# True
# 87

# %%
gdf_republique = routes_gdf.loc[routes_gdf['name'] == routes_pietonisation] #le geodataframe du Boulevard de la République
len(gdf_republique)
# Out:
# 4

# %% [markdown]
# ## Test

# %%
buffered = buffer_route(route,100)
buffered
# Out:
# C:\Users\mathieu.rajerison\AppData\Local\Temp\ipykernel_19696\47775820.py:43: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   routes_buffered_union = routes_buffered.unary_union
#                                             geometry
# 0  POLYGON ((6.3586 43.49227, 6.3583 43.49229, 6....

# %%
features = get_mapillary_data_bb(6.35692978371443, 43.49219720782365, 6.361864866173852, 43.494091792618796)
features
# Out:
# [[{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357066035270691, 43.491638644507645]},
#    'properties': {'first_seen_at': 1514556563000,
#     'id': 314073356764287,
#     'last_seen_at': 1514556563000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359909176826477, 43.49319143287087]},
#    'properties': {'first_seen_at': 1514556488000,
#     'id': 519922662712800,
#     'last_seen_at': 1514556488000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366968750953674, 43.49219516222058]},
#    'properties': {'first_seen_at': 1462276614772,
#     'id': 513895320048058,
#     'last_seen_at': 1462276614772,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368304491043091, 43.49317197461707]},
#    'properties': {'first_seen_at': 1634203332676,
#     'id': 943497122922387,
#     'last_seen_at': 1634203332676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367220878601074, 43.49219516222058]},
#    'properties': {'first_seen_at': 1462279647052,
#     'id': 823921781875789,
#     'last_seen_at': 1462279647052,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3601720333099365, 43.49809860429704]},
#    'properties': {'first_seen_at': 1634203561672,
#     'id': 526623355592433,
#     'last_seen_at': 1634203561672,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354496479034424, 43.49465856714761]},
#    'properties': {'first_seen_at': 1560612819340,
#     'id': 946984742779279,
#     'last_seen_at': 1560676591423,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3656169176101685, 43.49056062008438]},
#    'properties': {'first_seen_at': 1634203287677,
#     'id': 124175740023228,
#     'last_seen_at': 1634203287677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360563635826111, 43.49316029966181]},
#    'properties': {'first_seen_at': 1514556491000,
#     'id': 520040699367663,
#     'last_seen_at': 1514556491000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363648176193237, 43.495152792684394]},
#    'properties': {'first_seen_at': 1634203408673,
#     'id': 267716402001450,
#     'last_seen_at': 1634203408673,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.352908611297607, 43.498219235527245]},
#    'properties': {'first_seen_at': 1445770107803,
#     'id': 920386121859472,
#     'last_seen_at': 1445782247867,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354002952575684, 43.49175539690046]},
#    'properties': {'first_seen_at': 1445770039401,
#     'id': 217472769930530,
#     'last_seen_at': 1462284327900,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367553472518921, 43.49482979535057]},
#    'properties': {'first_seen_at': 1634203357176,
#     'id': 289711236287749,
#     'last_seen_at': 1634203357176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3636428117752075, 43.49523062310894]},
#    'properties': {'first_seen_at': 1634203412173,
#     'id': 267716395334784,
#     'last_seen_at': 1634203412173,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357618570327759, 43.492265213037854]},
#    'properties': {'first_seen_at': 1514556549000,
#     'id': 314088386762784,
#     'last_seen_at': 1514556549000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367467641830444, 43.49221462078904]},
#    'properties': {'first_seen_at': 1462276611783,
#     'id': 513828420054748,
#     'last_seen_at': 1462276611783,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354040503501892, 43.49205506034227]},
#    'properties': {'first_seen_at': 1445770043407,
#     'id': 217335553277585,
#     'last_seen_at': 1445770043407,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359002590179443, 43.49321867441563]},
#    'properties': {'first_seen_at': 1514556519000,
#     'id': 519901982714868,
#     'last_seen_at': 1514556519000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353139281272888, 43.49812195229589]},
#    'properties': {'first_seen_at': 1445770105505,
#     'id': 485914899127498,
#     'last_seen_at': 1445770107803,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367210149765015, 43.49456516974138]},
#    'properties': {'first_seen_at': 1634203353676,
#     'id': 289711282954411,
#     'last_seen_at': 1634203353676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3600754737854, 43.49318364957011]},
#    'properties': {'first_seen_at': 1506605522353,
#     'id': 4114634248574746,
#     'last_seen_at': 1506605522353,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368776559829712, 43.49210954444467]},
#    'properties': {'first_seen_at': 1462276598262,
#     'id': 4284504914902598,
#     'last_seen_at': 1462276598262,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363674998283386, 43.49535904309013]},
#    'properties': {'first_seen_at': 1634203422173,
#     'id': 267716398668117,
#     'last_seen_at': 1634203422173,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353943943977356, 43.4985577799506]},
#    'properties': {'first_seen_at': 1445770118446,
#     'id': 493351081717910,
#     'last_seen_at': 1445770118446,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364506483078003, 43.48936971152921]},
#    'properties': {'first_seen_at': 1634203262177,
#     'id': 124175766689892,
#     'last_seen_at': 1634203262177,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.362113952636719, 43.49027262474334]},
#    'properties': {'first_seen_at': 1560612684073,
#     'id': 831496207719863,
#     'last_seen_at': 1560612684073,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354238986968994, 43.49316808296558]},
#    'properties': {'first_seen_at': 1462284345889,
#     'id': 338044954330851,
#     'last_seen_at': 1462284345889,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359935998916626, 43.49241309782968]},
#    'properties': {'first_seen_at': 1514556474000,
#     'id': 520035779368155,
#     'last_seen_at': 1514556474000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368969678878784, 43.49216013678145]},
#    'properties': {'first_seen_at': 1634203316176,
#     'id': 943497186255714,
#     'last_seen_at': 1634203316176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359469294548035, 43.49015976132972]},
#    'properties': {'first_seen_at': 1462271062887,
#     'id': 244003494144374,
#     'last_seen_at': 1462271062887,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364603042602539, 43.49013641025229]},
#    'properties': {'first_seen_at': 1462276560755,
#     'id': 4285695581450198,
#     'last_seen_at': 1462276560755,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364045143127441, 43.49021035529981]},
#    'properties': {'first_seen_at': 1634203278677,
#     'id': 124175730023229,
#     'last_seen_at': 1634203278677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363401412963867, 43.49567425461336]},
#    'properties': {'first_seen_at': 1634203441671,
#     'id': 443303430695746,
#     'last_seen_at': 1634203441671,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3552045822143555, 43.48925684642836]},
#    'properties': {'first_seen_at': 1462284021882,
#     'id': 225079732396683,
#     'last_seen_at': 1462284021882,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.352999806404114, 43.49791571132704]},
#    'properties': {'first_seen_at': 1462270918892,
#     'id': 486010549117933,
#     'last_seen_at': 1462270918892,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357822418212891, 43.48959933297988]},
#    'properties': {'first_seen_at': 1462284005383,
#     'id': 225250409046282,
#     'last_seen_at': 1462284005383,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353391408920288, 43.49740205151235]},
#    'properties': {'first_seen_at': 1445770100304,
#     'id': 465835994713058,
#     'last_seen_at': 1445770100304,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.35534405708313, 43.49001187102024]},
#    'properties': {'first_seen_at': 1445769975666,
#     'id': 2872209206426112,
#     'last_seen_at': 1445769975666,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365268230438232, 43.49037770428362]},
#    'properties': {'first_seen_at': 1634203285177,
#     'id': 124175736689895,
#     'last_seen_at': 1634203285177,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364737153053284, 43.48905057518192]},
#    'properties': {'first_seen_at': 1634203260177,
#     'id': 124175693356566,
#     'last_seen_at': 1634203260177,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357892155647278, 43.49258044071004]},
#    'properties': {'first_seen_at': 1514556544000,
#     'id': 314066746764948,
#     'last_seen_at': 1514556544000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367392539978027, 43.494643000923276]},
#    'properties': {'first_seen_at': 1634203354176,
#     'id': 289711182954421,
#     'last_seen_at': 1634203354176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.352436542510986, 43.498693975447566]},
#    'properties': {'first_seen_at': 1560676409313,
#     'id': 489404015650084,
#     'last_seen_at': 1560676409313,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358181834220886, 43.492992958388186]},
#    'properties': {'first_seen_at': 1514556529000,
#     'id': 520032569368476,
#     'last_seen_at': 1514556529000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3530319929122925, 43.497966298799724]},
#    'properties': {'first_seen_at': 1462270918892,
#     'id': 485894239129564,
#     'last_seen_at': 1462270920364,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.36833131313324, 43.49231191353755]},
#    'properties': {'first_seen_at': 1634203319176,
#     'id': 943497429589023,
#     'last_seen_at': 1634203319176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364468932151794, 43.490066356965855]},
#    'properties': {'first_seen_at': 1634203278677,
#     'id': 124175733356562,
#     'last_seen_at': 1634203278677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.362559199333191, 43.49589606914341]},
#    'properties': {'first_seen_at': 1634203465671,
#     'id': 443303460695743,
#     'last_seen_at': 1634203465671,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368588805198669, 43.49191106640646]},
#    'properties': {'first_seen_at': 1462276598262,
#     'id': 4285595588126864,
#     'last_seen_at': 1462276598262,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3657402992248535, 43.49474807285972]},
#    'properties': {'first_seen_at': 1634203374673,
#     'id': 267716312001459,
#     'last_seen_at': 1634203374673,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357382535934448, 43.491988901008966]},
#    'properties': {'first_seen_at': 1514556553000,
#     'id': 313977150107241,
#     'last_seen_at': 1514556553000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.35434091091156, 43.489529279070496]},
#    'properties': {'first_seen_at': 1462284294891,
#     'id': 331376648422874,
#     'last_seen_at': 1462284296376,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.361180543899536, 43.490319326783805]},
#    'properties': {'first_seen_at': 1514556672000,
#     'id': 464011838018751,
#     'last_seen_at': 1514556672000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359710693359375, 43.49308246656898]},
#    'properties': {'first_seen_at': 1514556514000,
#     'id': 519867949384938,
#     'last_seen_at': 1514556514000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367800235748291, 43.49402813185225]},
#    'properties': {'first_seen_at': 1634203345676,
#     'id': 289711266287746,
#     'last_seen_at': 1634203345676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356062889099121, 43.490700725429434]},
#    'properties': {'first_seen_at': 1514556584000,
#     'id': 314121303426159,
#     'last_seen_at': 1514556584000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360939145088196, 43.49705182640619]},
#    'properties': {'first_seen_at': 1634203528668,
#     'id': 453246056442024,
#     'last_seen_at': 1634203528668,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360113024711609, 43.49283339999781]},
#    'properties': {'first_seen_at': 1514556485000,
#     'id': 520095319362201,
#     'last_seen_at': 1514556485000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360107660293579, 43.49283339999781]},
#    'properties': {'first_seen_at': 1514556484000,
#     'id': 520775839294149,
#     'last_seen_at': 1514556484000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359882354736328, 43.49174372167133]},
#    'properties': {'first_seen_at': 1514556460000,
#     'id': 520154646022935,
#     'last_seen_at': 1514556460000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3571518659591675, 43.489291873551224]},
#    'properties': {'first_seen_at': 1514556637000,
#     'id': 464172341336034,
#     'last_seen_at': 1514556637000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3607728481292725, 43.49037381245205]},
#    'properties': {'first_seen_at': 1462271071894,
#     'id': 244202534124470,
#     'last_seen_at': 1462271074895,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.35459303855896, 43.48969662994142]},
#    'properties': {'first_seen_at': 1462284294891,
#     'id': 331507478409791,
#     'last_seen_at': 1462284294891,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363433599472046, 43.49017143686504]},
#    'properties': {'first_seen_at': 1560612673972,
#     'id': 942666669608255,
#     'last_seen_at': 1560612673972,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354196071624756, 43.49287620838783]},
#    'properties': {'first_seen_at': 1445770051412,
#     'id': 217419249935882,
#     'last_seen_at': 1445770051412,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366029977798462, 43.486855494133096]},
#    'properties': {'first_seen_at': 1634203235671,
#     'id': 392970309185648,
#     'last_seen_at': 1634203235671,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353268027305603, 43.49832819256028]},
#    'properties': {'first_seen_at': 1462284417871,
#     'id': 235850264966809,
#     'last_seen_at': 1462284417871,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367269158363342, 43.49148297429946]},
#    'properties': {'first_seen_at': 1462276580280,
#     'id': 4284029928283430,
#     'last_seen_at': 1462276580280,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.355569362640381, 43.48929576545248]},
#    'properties': {'first_seen_at': 1462284018881,
#     'id': 225108942393762,
#     'last_seen_at': 1462284018881,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364409923553467, 43.494802554532555]},
#    'properties': {'first_seen_at': 1634203390673,
#     'id': 267716278668129,
#     'last_seen_at': 1634203390673,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.361566781997681, 43.496569290710255]},
#    'properties': {'first_seen_at': 1634203493168,
#     'id': 453246053108691,
#     'last_seen_at': 1634203493168,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360182762145996, 43.490241490029575]},
#    'properties': {'first_seen_at': 1462271070366,
#     'id': 244153834129340,
#     'last_seen_at': 1462271070366,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359152793884277, 43.49005468141024]},
#    'properties': {'first_seen_at': 1514556656000,
#     'id': 464001408019794,
#     'last_seen_at': 1560612714272,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354914903640747, 43.49517614182227]},
#    'properties': {'first_seen_at': 1445770071405,
#     'id': 774746160070868,
#     'last_seen_at': 1445770071405,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354061961174011, 43.49151021661487]},
#    'properties': {'first_seen_at': 1462284323400,
#     'id': 337997934335553,
#     'last_seen_at': 1462284323400,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359260082244873, 43.49324202430134]},
#    'properties': {'first_seen_at': 1514556517000,
#     'id': 520027506035649,
#     'last_seen_at': 1514556517000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365981698036194, 43.49073964352314]},
#    'properties': {'first_seen_at': 1634203290677,
#     'id': 124175746689894,
#     'last_seen_at': 1634203290677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360070109367371, 43.490572295542194]},
#    'properties': {'first_seen_at': 1462283981389,
#     'id': 489269105460334,
#     'last_seen_at': 1462283981389,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363621354103088, 43.49011305916585]},
#    'properties': {'first_seen_at': 1462283958867,
#     'id': 1646168232440120,
#     'last_seen_at': 1462283958867,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357033848762512, 43.49175539690046]},
#    'properties': {'first_seen_at': 1514556560000,
#     'id': 314116253426664,
#     'last_seen_at': 1514556560000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3672637939453125, 43.48535703306564]},
#    'properties': {'first_seen_at': 1634203222171,
#     'id': 392970325852313,
#     'last_seen_at': 1634203222171,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358385682106018, 43.49326537417804]},
#    'properties': {'first_seen_at': 1514556526000,
#     'id': 519993439372389,
#     'last_seen_at': 1514556526000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357747316360474, 43.49240920612925]},
#    'properties': {'first_seen_at': 1514556547000,
#     'id': 314126830092273,
#     'last_seen_at': 1514556547000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356513500213623, 43.4911716326794]},
#    'properties': {'first_seen_at': 1514556573000,
#     'id': 314007333437556,
#     'last_seen_at': 1514556573000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364147067070007, 43.49030375944099]},
#    'properties': {'first_seen_at': 1462279691962,
#     'id': 589497678694484,
#     'last_seen_at': 1462279691962,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364345550537109, 43.490128626557805]},
#    'properties': {'first_seen_at': 1462276556286,
#     'id': 4284472544905835,
#     'last_seen_at': 1462276556286,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3677144050598145, 43.49330818226187]},
#    'properties': {'first_seen_at': 1634203338176,
#     'id': 943497322922367,
#     'last_seen_at': 1634203338176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360284686088562, 43.49050613458462]},
#    'properties': {'first_seen_at': 1462283979891,
#     'id': 488486632205248,
#     'last_seen_at': 1462283981389,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3569265604019165, 43.49162696925595]},
#    'properties': {'first_seen_at': 1514556566000,
#     'id': 314079250097031,
#     'last_seen_at': 1514556566000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357457637786865, 43.492222404214715]},
#    'properties': {'first_seen_at': 1514556550000,
#     'id': 314014800103476,
#     'last_seen_at': 1514556550000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360011100769043, 43.49029208393125]},
#    'properties': {'first_seen_at': 1514556666000,
#     'id': 464148764671725,
#     'last_seen_at': 1514556666000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.35458767414093, 43.49489206003125]},
#    'properties': {'first_seen_at': 1462270954883,
#     'id': 319696133012643,
#     'last_seen_at': 1462284375882,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366287469863892, 43.4946546755919]},
#    'properties': {'first_seen_at': 1634203367173,
#     'id': 267716382001452,
#     'last_seen_at': 1634203367173,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353917121887207, 43.48914787302746]},
#    'properties': {'first_seen_at': 1462271011896,
#     'id': 840361286551669,
#     'last_seen_at': 1462271011896,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.36506974697113, 43.494895951571664]},
#    'properties': {'first_seen_at': 1634203384173,
#     'id': 267716272001463,
#     'last_seen_at': 1634203384173,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364136338233948, 43.49000019545406]},
#    'properties': {'first_seen_at': 1462276551800,
#     'id': 4285358131483943,
#     'last_seen_at': 1462276551800,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360290050506592, 43.4983826710031]},
#    'properties': {'first_seen_at': 1634203570172,
#     'id': 526623382259097,
#     'last_seen_at': 1634203570172,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359957456588745, 43.49162696925595]},
#    'properties': {'first_seen_at': 1514556462000,
#     'id': 520095446028855,
#     'last_seen_at': 1514556462000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368653178215027, 43.49217959536125]},
#    'properties': {'first_seen_at': 1634203316676,
#     'id': 943497446255688,
#     'last_seen_at': 1634203316676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356770992279053, 43.49145962373362]},
#    'properties': {'first_seen_at': 1514556567000,
#     'id': 313973973440892,
#     'last_seen_at': 1514556567000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368728280067444, 43.491833231703595]},
#    'properties': {'first_seen_at': 1634203313176,
#     'id': 943497119589054,
#     'last_seen_at': 1634203313176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360000371932983, 43.492093977563286]},
#    'properties': {'first_seen_at': 1514556470000,
#     'id': 520030536035346,
#     'last_seen_at': 1514556470000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363916397094727, 43.489669386808]},
#    'properties': {'first_seen_at': 1634203268677,
#     'id': 124175713356564,
#     'last_seen_at': 1634203268677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359362006187439, 43.49008192436986]},
#    'properties': {'first_seen_at': 1514556659000,
#     'id': 464054398014495,
#     'last_seen_at': 1514556659000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.362253427505493, 43.49619960349577]},
#    'properties': {'first_seen_at': 1634203481171,
#     'id': 443303437362412,
#     'last_seen_at': 1634203481171,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356282830238342, 43.48941641426785]},
#    'properties': {'first_seen_at': 1560676664493,
#     'id': 312984573782126,
#     'last_seen_at': 1560676664493,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365944147109985, 43.49468580803057]},
#    'properties': {'first_seen_at': 1634203373173,
#     'id': 267716315334792,
#     'last_seen_at': 1634203373173,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364978551864624, 43.488536839958925]},
#    'properties': {'first_seen_at': 1560612642446,
#     'id': 327694208701643,
#     'last_seen_at': 1634203255677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363921761512756, 43.494907626191406]},
#    'properties': {'first_seen_at': 1634203404673,
#     'id': 267716318668125,
#     'last_seen_at': 1634203404673,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366496682167053, 43.486224977382506]},
#    'properties': {'first_seen_at': 1634203228671,
#     'id': 392970369185642,
#     'last_seen_at': 1634203228671,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.36833131313324, 43.49231191353755]},
#    'properties': {'first_seen_at': 1634203318176,
#     'id': 943497166255716,
#     'last_seen_at': 1634203318176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359260082244873, 43.49323424100709]},
#    'properties': {'first_seen_at': 1514556519000,
#     'id': 519910316047368,
#     'last_seen_at': 1514556519000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360805034637451, 43.4930630082801]},
#    'properties': {'first_seen_at': 1514556495000,
#     'id': 520058459365887,
#     'last_seen_at': 1514556495000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363707184791565, 43.48988733153138]},
#    'properties': {'first_seen_at': 1462271095908,
#     'id': 501961550948839,
#     'last_seen_at': 1462271095908,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358766555786133, 43.48991457456651]},
#    'properties': {'first_seen_at': 1462271058367,
#     'id': 244137487464308,
#     'last_seen_at': 1514556653000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359962821006775, 43.4916503197571]},
#    'properties': {'first_seen_at': 1514556460000,
#     'id': 520045849367148,
#     'last_seen_at': 1514556460000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363176107406616, 43.49016754502017]},
#    'properties': {'first_seen_at': 1514556684000,
#     'id': 464084188011516,
#     'last_seen_at': 1514556684000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3532304763793945, 43.497654990603564]},
#    'properties': {'first_seen_at': 1560612868532,
#     'id': 1013605789172707,
#     'last_seen_at': 1560612868532,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360139846801758, 43.49789236324847]},
#    'properties': {'first_seen_at': 1634203554672,
#     'id': 600690251080368,
#     'last_seen_at': 1634203560172,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366684436798096, 43.48571511025912]},
#    'properties': {'first_seen_at': 1634203227171,
#     'id': 392970305852315,
#     'last_seen_at': 1634203227171,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368030905723572, 43.49224186277445]},
#    'properties': {'first_seen_at': 1634203323676,
#     'id': 943497129589053,
#     'last_seen_at': 1634203323676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363680362701416, 43.49013641025229]},
#    'properties': {'first_seen_at': 1560612672342,
#     'id': 863636511172312,
#     'last_seen_at': 1560612672342,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364238262176514, 43.49006246511422]},
#    'properties': {'first_seen_at': 1634203275677,
#     'id': 124175710023231,
#     'last_seen_at': 1634203275677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358305215835571, 43.49312916643672]},
#    'properties': {'first_seen_at': 1506606111654,
#     'id': 217688179922505,
#     'last_seen_at': 1506606111654,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366244554519653, 43.48645071870388]},
#    'properties': {'first_seen_at': 1560612625364,
#     'id': 491033278983794,
#     'last_seen_at': 1560612625364,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.35658323764801, 43.48936192773593]},
#    'properties': {'first_seen_at': 1514556634000,
#     'id': 464160378003897,
#     'last_seen_at': 1514556634000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357468366622925, 43.489529279070496]},
#    'properties': {'first_seen_at': 1560612730272,
#     'id': 476670250287312,
#     'last_seen_at': 1560612730272,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359952092170715, 43.49280615827925]},
#    'properties': {'first_seen_at': 1514556481000,
#     'id': 519991416039258,
#     'last_seen_at': 1514556481000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365171670913696, 43.48827607874213]},
#    'properties': {'first_seen_at': 1462276512776,
#     'id': 922643915199978,
#     'last_seen_at': 1634203252177,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358970403671265, 43.4932147827671]},
#    'properties': {'first_seen_at': 1506606018069,
#     'id': 294979979022413,
#     'last_seen_at': 1506606018069,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368106007575989, 43.49249871517526]},
#    'properties': {'first_seen_at': 1634203325176,
#     'id': 943497159589050,
#     'last_seen_at': 1634203325176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366984844207764, 43.494572952864075]},
#    'properties': {'first_seen_at': 1634203356676,
#     'id': 289711166287756,
#     'last_seen_at': 1634203356676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3580262660980225, 43.49271664968896]},
#    'properties': {'first_seen_at': 1514556535000,
#     'id': 519974109374322,
#     'last_seen_at': 1514556535000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364130973815918, 43.494639109366545]},
#    'properties': {'first_seen_at': 1634203402673,
#     'id': 267716235334800,
#     'last_seen_at': 1634203402673,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364297270774841, 43.48978225113794]},
#    'properties': {'first_seen_at': 1462276554789,
#     'id': 4285124508173972,
#     'last_seen_at': 1462276554789,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354802250862122, 43.48914008920559]},
#    'properties': {'first_seen_at': 1462284287371,
#     'id': 331260431767829,
#     'last_seen_at': 1462284287371,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3592976331710815, 43.49310192485157]},
#    'properties': {'first_seen_at': 1514556515000,
#     'id': 520048172700249,
#     'last_seen_at': 1514556515000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3599467277526855, 43.49279837492884]},
#    'properties': {'first_seen_at': 1514556484000,
#     'id': 519978662707200,
#     'last_seen_at': 1514556484000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358407139778137, 43.49326537417804]},
#    'properties': {'first_seen_at': 1514556527000,
#     'id': 519975736040826,
#     'last_seen_at': 1514556527000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363487243652344, 43.495440764754136]},
#    'properties': {'first_seen_at': 1634203415673,
#     'id': 267716225334801,
#     'last_seen_at': 1634203415673,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.35633111000061, 43.49096925976565]},
#    'properties': {'first_seen_at': 1514556579000,
#     'id': 314180226753600,
#     'last_seen_at': 1514556579000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3648927211761475, 43.49020257161487]},
#    'properties': {'first_seen_at': 1634203281677,
#     'id': 124175723356563,
#     'last_seen_at': 1634203281677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357795596122742, 43.49330429061911]},
#    'properties': {'first_seen_at': 1514556529000,
#     'id': 519900236048376,
#     'last_seen_at': 1514556529000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.36807918548584, 43.493031875004846]},
#    'properties': {'first_seen_at': 1634203331676,
#     'id': 943497302922369,
#     'last_seen_at': 1634203331676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366791725158691, 43.49460408534486]},
#    'properties': {'first_seen_at': 1634203360676,
#     'id': 289711229621083,
#     'last_seen_at': 1634203365673,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357178688049316, 43.49191106640646]},
#    'properties': {'first_seen_at': 1514556558000,
#     'id': 314130676758555,
#     'last_seen_at': 1514556558000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359469294548035, 43.49316808296558]},
#    'properties': {'first_seen_at': 1506606027174,
#     'id': 294977649022646,
#     'last_seen_at': 1506606027174,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.35833740234375, 43.49298906672516]},
#    'properties': {'first_seen_at': 1506606111330,
#     'id': 217801359911187,
#     'last_seen_at': 1506606111330,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356948018074036, 43.49151800013129]},
#    'properties': {'first_seen_at': 1514556566000,
#     'id': 313931290111827,
#     'last_seen_at': 1514556566000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360638737678528, 43.497363137712]},
#    'properties': {'first_seen_at': 1634203536168,
#     'id': 453246066442023,
#     'last_seen_at': 1634203536168,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360290050506592, 43.493148624704304]},
#    'properties': {'first_seen_at': 1223379952000,
#     'id': 534436874598692,
#     'last_seen_at': 1223379952000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359721422195435, 43.49308246656898]},
#    'properties': {'first_seen_at': 1514556514000,
#     'id': 520004676037932,
#     'last_seen_at': 1514556514000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364479660987854, 43.48951760341106]},
#    'properties': {'first_seen_at': 1462271104886,
#     'id': 533638294712765,
#     'last_seen_at': 1462271104886,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353976130485535, 43.489354143941625]},
#    'properties': {'first_seen_at': 1462271007373,
#     'id': 839744099946721,
#     'last_seen_at': 1462271007373,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359995007514954, 43.49210176100448]},
#    'properties': {'first_seen_at': 1514556469000,
#     'id': 520124362692630,
#     'last_seen_at': 1514556469000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3543301820755005, 43.488968844870556]},
#    'properties': {'first_seen_at': 1514556615000,
#     'id': 3965513153502555,
#     'last_seen_at': 1514556615000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366754174232483, 43.485933069250706]},
#    'properties': {'first_seen_at': 1514556729000,
#     'id': 933866857402006,
#     'last_seen_at': 1634203227171,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.36783242225647, 43.49377517756881]},
#    'properties': {'first_seen_at': 1634203342176,
#     'id': 289711172954422,
#     'last_seen_at': 1634203342176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363873481750488, 43.49026873290498]},
#    'properties': {'first_seen_at': 1462279694983,
#     'id': 589694722008113,
#     'last_seen_at': 1634203279177,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.355918049812317, 43.489315224955135]},
#    'properties': {'first_seen_at': 1462284017376,
#     'id': 225146785723311,
#     'last_seen_at': 1462284030862,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365429162979126, 43.49489984311185]},
#    'properties': {'first_seen_at': 1634203379173,
#     'id': 267716222001468,
#     'last_seen_at': 1634203379173,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357307434082031, 43.49205895206549]},
#    'properties': {'first_seen_at': 1514556553000,
#     'id': 313905560114400,
#     'last_seen_at': 1514556553000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368014812469482, 43.493277049113004]},
#    'properties': {'first_seen_at': 1634203335676,
#     'id': 943497162922383,
#     'last_seen_at': 1634203335676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353525519371033, 43.49708684900821]},
#    'properties': {'first_seen_at': 1445770096050,
#     'id': 465809304715727,
#     'last_seen_at': 1560612853766,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366260647773743, 43.48654023658048]},
#    'properties': {'first_seen_at': 1634203232171,
#     'id': 392970409185638,
#     'last_seen_at': 1634203232171,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353927850723267, 43.491354546075655]},
#    'properties': {'first_seen_at': 1445770037409,
#     'id': 217425879935219,
#     'last_seen_at': 1445770037409,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357296705245972, 43.49175928864301]},
#    'properties': {'first_seen_at': 1514556559000,
#     'id': 314208870084069,
#     'last_seen_at': 1514556559000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357505917549133, 43.492125111322025]},
#    'properties': {'first_seen_at': 1514556553000,
#     'id': 314011383437151,
#     'last_seen_at': 1514556553000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.362355351448059, 43.49602448770946]},
#    'properties': {'first_seen_at': 1634203467171,
#     'id': 443303397362416,
#     'last_seen_at': 1634203467171,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353901028633118, 43.49622295222889]},
#    'properties': {'first_seen_at': 1560612843772,
#     'id': 530134464685939,
#     'last_seen_at': 1560612843772,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367692947387695, 43.49433556717031]},
#    'properties': {'first_seen_at': 1634203351176,
#     'id': 289711226287750,
#     'last_seen_at': 1634203351176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365150213241577, 43.488159319623435]},
#    'properties': {'first_seen_at': 1560612639037,
#     'id': 147094230735861,
#     'last_seen_at': 1560612639037,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358541250228882, 43.48968884619026]},
#    'properties': {'first_seen_at': 1514556649000,
#     'id': 463969161356352,
#     'last_seen_at': 1514556649000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365547180175781, 43.4875443845406]},
#    'properties': {'first_seen_at': 1634203243677,
#     'id': 124175703356565,
#     'last_seen_at': 1634203243677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3601237535476685, 43.49308635822601]},
#    'properties': {'first_seen_at': 1514556485000,
#     'id': 520122669359466,
#     'last_seen_at': 1514556485000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366346478462219, 43.49092255822774]},
#    'properties': {'first_seen_at': 1634203293177,
#     'id': 124175743356561,
#     'last_seen_at': 1634203293177,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.35408878326416, 43.49231969695066]},
#    'properties': {'first_seen_at': 1445770045405,
#     'id': 217431823267958,
#     'last_seen_at': 1462284333905,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354625225067139, 43.489108953908044]},
#    'properties': {'first_seen_at': 1445769950060,
#     'id': 489449012337131,
#     'last_seen_at': 1445769950060,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.36807918548584, 43.49275167480528]},
#    'properties': {'first_seen_at': 1634203328676,
#     'id': 943497246255708,
#     'last_seen_at': 1634203328676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357468366622925, 43.489521495297794]},
#    'properties': {'first_seen_at': 1560612730272,
#     'id': 1052486928857161,
#     'last_seen_at': 1560612730272,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368642449378967, 43.49249482348034]},
#    'properties': {'first_seen_at': 1634203317676,
#     'id': 943497482922351,
#     'last_seen_at': 1634203317676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354426741600037, 43.495113877434505]},
#    'properties': {'first_seen_at': 1462270948892,
#     'id': 319670156348574,
#     'last_seen_at': 1462270948892,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367848515510559, 43.49173204643995]},
#    'properties': {'first_seen_at': 1634203304676,
#     'id': 943497126255720,
#     'last_seen_at': 1634203304676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356615424156189, 43.491315628378175]},
#    'properties': {'first_seen_at': 1514556570000,
#     'id': 314157820089174,
#     'last_seen_at': 1514556570000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.36059045791626, 43.49860836688532]},
#    'properties': {'first_seen_at': 1634203572672,
#     'id': 526623358925766,
#     'last_seen_at': 1634203572672,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354040503501892, 43.48957987356877]},
#    'properties': {'first_seen_at': 1445770007542,
#     'id': 783375342539976,
#     'last_seen_at': 1445770007542,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360874772071838, 43.49312527478244]},
#    'properties': {'first_seen_at': 1514556496000,
#     'id': 519952189376514,
#     'last_seen_at': 1514556496000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3684868812561035, 43.49184490691542]},
#    'properties': {'first_seen_at': 1634203311176,
#     'id': 943497256255707,
#     'last_seen_at': 1634203311176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354271173477173, 43.493409364884826]},
#    'properties': {'first_seen_at': 1462284348915,
#     'id': 338001014335245,
#     'last_seen_at': 1560612808350,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360037922859192, 43.49258433239942]},
#    'properties': {'first_seen_at': 1514556478000,
#     'id': 520632569308476,
#     'last_seen_at': 1514556478000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358814835548401, 43.49322645771187]},
#    'properties': {'first_seen_at': 1506606053094,
#     'id': 294859669034444,
#     'last_seen_at': 1506606053094,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358353495597839, 43.4896265761449]},
#    'properties': {'first_seen_at': 1462271052363,
#     'id': 244061930805197,
#     'last_seen_at': 1462271052363,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359957456588745, 43.49307079159638]},
#    'properties': {'first_seen_at': 1506605517399,
#     'id': 4115170248521146,
#     'last_seen_at': 1506605517399,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365278959274292, 43.488050344242396]},
#    'properties': {'first_seen_at': 1634203247177,
#     'id': 124175700023232,
#     'last_seen_at': 1634203247177,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357994079589844, 43.49283729167087]},
#    'properties': {'first_seen_at': 1514556533000,
#     'id': 520173199354413,
#     'last_seen_at': 1514556533000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358986496925354, 43.493117491473186]},
#    'properties': {'first_seen_at': 1506606023870,
#     'id': 294913889029022,
#     'last_seen_at': 1506606023870,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360450983047485, 43.49897025679769]},
#    'properties': {'first_seen_at': 1634203582172,
#     'id': 526623428925759,
#     'last_seen_at': 1634203582172,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.358181834220886, 43.49288010005813]},
#    'properties': {'first_seen_at': 1514556531000,
#     'id': 520081332696933,
#     'last_seen_at': 1514556531000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.359914541244507, 43.49219516222058]},
#    'properties': {'first_seen_at': 1514556470000,
#     'id': 519849619386771,
#     'last_seen_at': 1514556470000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360182762145996, 43.493156408009554]},
#    'properties': {'first_seen_at': 1223380132000,
#     'id': 1101151630394242,
#     'last_seen_at': 1223380132000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360225677490234, 43.499838005493444]},
#    'properties': {'first_seen_at': 1634203603172,
#     'id': 526623425592426,
#     'last_seen_at': 1634203603172,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354700326919556, 43.48936971152921]},
#    'properties': {'first_seen_at': 1462284290370,
#     'id': 331342555092950,
#     'last_seen_at': 1462284290370,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.361625790596008, 43.49029986760465]},
#    'properties': {'first_seen_at': 1514556675000,
#     'id': 464151601338108,
#     'last_seen_at': 1514556675000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354432106018066, 43.4943316755938]},
#    'properties': {'first_seen_at': 1462284360912,
#     'id': 338056697663010,
#     'last_seen_at': 1462284360912,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353783011436462, 43.49009359992024]},
#    'properties': {'first_seen_at': 1560612767510,
#     'id': 152367563570198,
#     'last_seen_at': 1560612767510,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.352500915527344, 43.49851108428092]},
#    'properties': {'first_seen_at': 1560612976458,
#     'id': 4003590103066361,
#     'last_seen_at': 1560612976458,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3670814037323, 43.491288385975025]},
#    'properties': {'first_seen_at': 1634203298177,
#     'id': 124175756689893,
#     'last_seen_at': 1634203298177,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356422305107117, 43.491194983356564]},
#    'properties': {'first_seen_at': 1514556576000,
#     'id': 313910180113938,
#     'last_seen_at': 1514556576000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367923617362976, 43.49349887244841]},
#    'properties': {'first_seen_at': 1634203339176,
#     'id': 943497416255691,
#     'last_seen_at': 1634203339176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368642449378967, 43.49249871517526]},
#    'properties': {'first_seen_at': 1634203310176,
#     'id': 943497252922374,
#     'last_seen_at': 1634203310176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354147791862488, 43.49260379084254]},
#    'properties': {'first_seen_at': 1445770049512,
#     'id': 217288513282289,
#     'last_seen_at': 1445770049512,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365799307823181, 43.48706955696545]},
#    'properties': {'first_seen_at': 1560612626465,
#     'id': 3892233570883539,
#     'last_seen_at': 1560612626465,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356749534606934, 43.48941252237435]},
#    'properties': {'first_seen_at': 1514556634000,
#     'id': 464029331350335,
#     'last_seen_at': 1514556634000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357822418212891, 43.489603224861355]},
#    'properties': {'first_seen_at': 1462284005383,
#     'id': 225112102393446,
#     'last_seen_at': 1462284005383,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356658339500427, 43.49118330801909]},
#    'properties': {'first_seen_at': 1514556570000,
#     'id': 313931880111768,
#     'last_seen_at': 1514556570000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356497406959534, 43.49100817768635]},
#    'properties': {'first_seen_at': 1514556577000,
#     'id': 314023713435918,
#     'last_seen_at': 1514556577000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366620063781738, 43.494627434694934]},
#    'properties': {'first_seen_at': 1634203365673,
#     'id': 267716385334785,
#     'last_seen_at': 1634203365673,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3642436265945435, 43.48967327868493]},
#    'properties': {'first_seen_at': 1634203264677,
#     'id': 124175726689896,
#     'last_seen_at': 1634203264677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.363111734390259, 43.495421307225115]},
#    'properties': {'first_seen_at': 1634203449671,
#     'id': 443303390695750,
#     'last_seen_at': 1634203449671,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.352758407592773, 43.49848773643254]},
#    'properties': {'first_seen_at': 1445770107803,
#     'id': 920256271872457,
#     'last_seen_at': 1560676545418,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365370154380798, 43.487820716902974]},
#    'properties': {'first_seen_at': 1560612636458,
#     'id': 122858603180401,
#     'last_seen_at': 1634203245177,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.368036270141602, 43.49361172962213]},
#    'properties': {'first_seen_at': 1634203339176,
#     'id': 943497352922364,
#     'last_seen_at': 1634203339176,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.354383826255798, 43.49403591504418]},
#    'properties': {'first_seen_at': 1462284357915,
#     'id': 338049510997062,
#     'last_seen_at': 1462284357915,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.35334849357605, 43.49853054081436]},
#    'properties': {'first_seen_at': 1445770114377,
#     'id': 920256981872386,
#     'last_seen_at': 1445770114377,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353702545166016, 43.4966354450257]},
#    'properties': {'first_seen_at': 1509975415115,
#     'id': 1037238720140798,
#     'last_seen_at': 1509975415115,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.365788578987122, 43.487178534116]},
#    'properties': {'first_seen_at': 1634203238671,
#     'id': 392970365852309,
#     'last_seen_at': 1634203238671,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353042721748352, 43.49848773643254]},
#    'properties': {'first_seen_at': 1445770109880,
#     'id': 920144498550301,
#     'last_seen_at': 1445770109880,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3600969314575195, 43.49318364957011]},
#    'properties': {'first_seen_at': 1514556489000,
#     'id': 519891216049278,
#     'last_seen_at': 1514556489000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356787085533142, 43.491323411919666]},
#    'properties': {'first_seen_at': 1514556569000,
#     'id': 314016300103326,
#     'last_seen_at': 1514556569000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.353783011436462, 43.49036602878817]},
#    'properties': {'first_seen_at': 1445770015401,
#     'id': 512341346620726,
#     'last_seen_at': 1445770015401,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.357886791229248, 43.4896849543143]},
#    'properties': {'first_seen_at': 1462271046366,
#     'id': 244194677458589,
#     'last_seen_at': 1462271046366,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366984844207764, 43.48565283611708]},
#    'properties': {'first_seen_at': 1560612614467,
#     'id': 485886249299698,
#     'last_seen_at': 1634203223671,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.360461711883545, 43.49308635822601]},
#    'properties': {'first_seen_at': 1514556486000,
#     'id': 519940312711035,
#     'last_seen_at': 1514556486000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.364737153053284, 43.49485703615625]},
#    'properties': {'first_seen_at': 1634203386673,
#     'id': 267716232001467,
#     'last_seen_at': 1634203386673,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3642919063568115, 43.48993792572969]},
#    'properties': {'first_seen_at': 1462276559261,
#     'id': 4284882198198203,
#     'last_seen_at': 1634203276677,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.356390118598938, 43.48933079255275]},
#    'properties': {'first_seen_at': 1462284017376,
#     'id': 225077272396929,
#     'last_seen_at': 1462284017376,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.3598984479904175, 43.491883824271866]},
#    'properties': {'first_seen_at': 1514556460000,
#     'id': 519970042708062,
#     'last_seen_at': 1514556460000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.355741024017334, 43.490358245123275]},
#    'properties': {'first_seen_at': 1514556588000,
#     'id': 314878870017069,
#     'last_seen_at': 1514556588000,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.367623209953308, 43.494572952864075]},
#    'properties': {'first_seen_at': 1634203354676,
#     'id': 289711199621086,
#     'last_seen_at': 1634203354676,
#     'value': 'object--street-light'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [6.366705894470215, 43.49110158059369]},
#    'properties': {'first_seen_at': 1634203295177,
#     'id': 124175763356559,
#     'last_seen_at': 1634203295177,
#     'value': 'object--street-light'}}]]

# %%
len(features)
# Out:
# 1

# %%
len(features[0])
# Out:
# 240

# %%
len(features[0][0])
# Out:
# 3

# %%
features[0][0]['geometry']
# Out:
# {'type': 'Point', 'coordinates': [6.357066035270691, 43.491638644507645]}

# %%
features2 = features[0]
feat = features2[0]
geom = shape(features2[0]['geometry'])
geom.intersects(polygon).iloc[0]
if geom.intersects(polygon).iloc[0].all():
    print(True)
else:
    print(False)
# Out:
# False

# %%
polygon = buffered
filtered_features = []
features2 = features[0]
for feature in features2:
    geom = shape(feature['geometry'])
    if (geom.intersects(polygon).values.all()):
        filtered_features.append(feature)
        
print(len(filtered_features), '/', len(features2))
# Out:
# 38
# 240

# %% [markdown]
# ## Fonctions

# %%
import mercantile
import requests
from vt2geojson.tools import vt_bytes_to_geojson
from concurrent.futures import ThreadPoolExecutor
from shapely.geometry import box, shape
import geopandas as gpd
import os, json
import functools

# Choix de type de tuiles vectorielles
def choose_data_type(data_type):
    """
    Choisie le type des entités à récupérer
    
    Cette fonction prend en entrée le type de données tuiles des entités à récupérer ("tile_points" pour les points ou "tile_traffic_signs" pour
    les paneaux de signalisation) et retourne le type des entités à récupérer.
    
    Paramètres :
    - data_type (str) : le type de données tuiles des entités à récupérer.

    Retour :
    - 'mly_map_feature_point' (str) : la clé mapillary décrivant les entités "points".
    - 'mly_map_feature_traffic_sign' (str) : la clé mapillary décrivant les entités "traffic_signs".
    """
    if (data_type == "tile_points"):
        return("mly_map_feature_point")
    elif (data_type == "tile_traffic_signs"):
        return("mly_map_feature_traffic_sign")

# Charger le fichier tabulaire contenant la clé Token d'accès Mapillary
with open("../notebooks/mapillary_token.txt", encoding="utf-8") as f:
    access_token = f.read()

# Fonction pour créer la zone tampon
def buffer_route(routes_gdf,d): #Création d'une zone tampon de la route   
        
    routes_gdf = routes_gdf.to_crs(epsg=2154) #pour prendre en concidération la distance en mètres avant la réalisation du buffer
    
    routes_buffered = routes_gdf.buffer(d,resolution=20)
    
    routes_buffered = routes_buffered.to_crs(epsg=4326)
 
    routes_buffered_union = routes_buffered.unary_union
    
    gdf_routes_buffered_union = gpd.GeoDataFrame(geometry=[routes_buffered_union])

    return(gdf_routes_buffered_union)

# Fonction pour filtrer les entités qui intersectent la zone tampon
def filter_features(features, polygon):

    """
    Récupérer les entités qui intersectent un polygone.
    
    Cette fonction prend en entrée les dictionnaires des données des entités et un polygone d'intersection et retourne les entités qui intersectent
    le polygone.
    
    Paramètres :
    - features (dict) : dictionnaires des données des entités.
    - polygon (hapely.geometry.Polygon) : polygone d'intersection.

    Retour :
    - filtered_features (dict) : dictionnaire des entités qui intersectent le polygone.
    """
    filtered_features = []
    for feature in features:
        geom = shape(feature['geometry'])
        if geom.intersects(polygon).values.all():
            filtered_features.append(feature)
    return filtered_features

# Fonction pour récupérer les données d'une tuile vectorielle
def fetch_tile(tile, data_type):
    """
    Chercher et récupérer les données des entités à partir d'une tuile vectorielle.
    
    Cette fonction prend en entrée une tuile vectorielle ainsi que le type de données tuiles à récupérer et retourne le dictionnaire des données
    des entités contenues dans cette tuile.
    
    Paramètres :
    - tile (mercantile.Tile) : tuile vectorielle.
    - data_type (str) : le type de données tuiles des entités à récupérer.

    Retour :
    - data['features'] (dict) : dictionnaire des données des entités contenues dans la tuile.
    """
    tile_url = f'https://tiles.mapillary.com/maps/vtp/{choose_data_type(data_type)}/2/{tile.z}/{tile.x}/{tile.y}?access_token={access_token}'
    response = requests.get(tile_url)
    data = vt_bytes_to_geojson(response.content, tile.x, tile.y, tile.z)

    #choisir les type selon les valeurs des entités
    filtered_data = [feature for feature in data['features'] if feature['properties']['value'] in filter_values]
    return (filtered_data)

#def fetch_tile_traffic_sign(tile):
    #return fetch_tile(tile, 'tile_traffic_signs')

#def fetch_tile_points(tile):
    #return fetch_tile(tile, 'tile_points')
    
def get_mapillary_data_bb(W, S, E, N):

    # Récupérer la liste des tuiles intersectant notre bounding box
    tiles = list(mercantile.tiles(W, S, E, N, 14))
    
    # Créer un polygone à partir de la bounding box
    bbox_polygon = box(W, S, E, N)
    gdf_bbox = gpd.GeoDataFrame({'geometry': [bbox_polygon]}, crs='EPSG:4326')

    # Utilisation de functools.partial pour fixer la valeur de l'argument 'data_type' dans la fonction fetch_tile
    partial_fetch_tile = functools.partial(fetch_tile, data_type=data_type)

    # Exécuter les requêtes en parallèle vu le nombre important des tuiles
    with ThreadPoolExecutor() as executor:
        results = list(executor.map(partial_fetch_tile, tiles))
        
    return(results)

# Récupérer les données (selon choix : points ou panneaux de signalisation) depuis l'API de Mapillary
def get_mapillary_data(data_type, access_token, highways, output_folder):

    """
    Récupérer les données de Mapillary à partir d'une bbox.
    
    Cette fonction prend en entrée le type de données tuiles des entités à récupérer ("tile_points" pour les points ou "tile_traffic_signs" pour
    les paneaux de signalisation), la clé Token d'accès Mapillary, ainsi que les coordonnées du bbox à partir duquel ces données sont extraites
    et retourne les données Mapillary catégorie "Points" incluses dans cette bbox.
    
    Paramètres :
    - data_type (str) : le type de données tuiles des entités à récupérer.
    - access_token (str) : la clé Token d'accès Mapillary.
    - W (float) : Longitude max de la bbox.
    - S (float) : Latitude min de la bbox.
    - E (float) : Longitude min de la bbox.
    - N (float) : Latitude max de la bbox.

    Retour :
    - gdf_mapillary (geopandas.GeoDataFrame) : Le GeoDataFrame des données Mapillary extraites.
    - gdf_bbox (geopandas.GeoDataFrame) : Le GeoDataFrame de la bbox.
    """
    # créer la zone tampon de la route choisie
    buffered = buffer_route(highways,100)
    
    # Les coordonnées du Bounding box de la zone tampon de la route choisie
    minx, miny, maxx, maxy = buffered.bounds['minx'].values[0],buffered.bounds['miny'].values[0],buffered.bounds['maxx'].values[0],buffered.bounds['maxy'].values[0]
    (W, S, E, N) = (minx, miny, maxx, maxy)
    
    print(W, S, E, N)
    features = get_mapillary_data_bb(W, S, E, N)
    
    # Définir un GeoJSON vide en tant que sortie
    output = {"type": "FeatureCollection", "features": []}

    # Filtrer les resultats des entités contenues dans la zone tampon
    for feat in features:
        filtered_features = filter_features(feat, buffered)
        output['features'].extend(filtered_features)

    # Export du fichier résultat sous fromat geojson
    with open(output_folder, "w") as fx:
        json.dump(output, fx)
        gdf_mapillary = gpd.GeoDataFrame.from_features(output)
    return(gdf_mapillary,buffered)

# Visualisation :
from ipyleaflet import Map, GeoJSON, GeoData, ZoomControl

import geopandas, pandas as pd, numpy as np

def render_map(data, pol):

    """
    Visualsation des données OSM extraites à partir d'un polygone quelconque (bbox ou buffer ou contour de commune/quartier...).
    
    Cette procedure prend en entrée les données OSM ainsi que le polygone à partir duquel ces données sont extraites et retourne
    les données OSM catégorie "transport" incluses dans cette zone.
    
    Paramètres :
    - data (geopandas.GeoDataFrame) : Le GeoDataFrame des données OSM extraites.
    - pol (geopandas.GeoDataFrame) : Le GeoDataFrame du polygone d'extraction. 
    """    
    
    m = Map(center=(pol.bounds['miny'].values[0],pol.bounds['minx'].values[0]))

    # Visualisation des données extraites
    geo_data1 = GeoData(geo_dataframe = data,
        style={'color': 'black', 'radius':3, 'fillColor': '#cc3333', 'opacity':1, 'weight':1, 'dashArray':'2', 'fillOpacity':1},
        hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
        point_style={'radius': 5, 'color': 'red', 'fillOpacity': 0.8, 'fillColor': 'blue', 'weight': 3},
        name = 'Release')

    # Visualisation du polygone d'extraction
    geo_data2 = GeoData(geo_dataframe = pol,
        style={'color': 'blue', 'radius':2, 'fillColor': '#004dff', 'opacity':1, 'weight':2, 'dashArray':'1', 'fillOpacity':0})
    
    m.add(geo_data2)
    m.add(geo_data1)

    m.fit_bounds([[pol.bounds['miny'].values[0], pol.bounds['minx'].values[0]], # Ajuster le zoom et centrer la carte pour afficher les limites du polygone
              [pol.bounds['maxy'].values[0], pol.bounds['maxx'].values[0]]])
    
    display(m)

route = gdf_republique
data_type = "tile_points"
filter_values = ["object--street-light"]
Name = "Eclairage_depuis_routes_Mly"
output_folder = "../data/processed/"+Name+".geojson"

# Donnée Mapillary à récupérer
Eclairage_mapillary, highways_buffered = get_mapillary_data(data_type, access_token, route, output_folder)
print("end")

# Rendu carto
render_map(Eclairage_mapillary, highways_buffered)
# Out:
# C:\Users\mathieu.rajerison\AppData\Local\Temp\ipykernel_19696\4150332627.py:43: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   routes_buffered_union = routes_buffered.unary_union
# 6.35692978371443 43.49219720782365 6.361864866173852 43.494091792618796
# C:\Git-Repos\cim\venv\Lib\site-packages\vt2geojson\tools.py:27: DeprecationWarning: `decode` signature has changed, use `default_options` instead
#   data = decode(b_content, y_coord_down=True)
# end
# Map(center=[np.float64(43.49219720782365), np.float64(6.35692978371443)], controls=(ZoomControl(options=['posi…
